# %%
# ------------------------------------------------------------
# STEP 1: LOAD DATA
# ------------------------------------------------------------

import pandas as pd
import numpy as np

url = "gs://agntworks-data-dev/wheelsup/processed/wingx/wingx_corridor_2026.csv"

df1 = pd.read_csv(url)

print("Shape:", df1.shape)
df1.head()
# Out:
# /opt/conda/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.20) which Google will stop supporting in new releases of google.cloud.storage_control_v2 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.storage_control_v2 past that date.
#   warnings.warn(message, FutureWarning)
# Shape: (180175, 7)
#                         corridor aircraft_segment      aircraft_model  \
# 0  ASPEN_CLUSTER→ATLANTA_CLUSTER  Entry Level Jet  no model available
# 1  ASPEN_CLUSTER→ATLANTA_CLUSTER  Entry Level Jet  no model available
# 2  ASPEN_CLUSTER→ATLANTA_CLUSTER        Heavy Jet   Challenger 601-3A
# 3  ASPEN_CLUSTER→ATLANTA_CLUSTER        Heavy Jet      Challenger 604
# 4  ASPEN_CLUSTER→ATLANTA_CLUSTER        Heavy Jet      Challenger 604
#
#                   Operator                operator_type  flights     hours
# 0  Barnstormer Leasing LLC  Corporate Flight Department        1  2.533333
# 1      Rex Air Bristol LLC    Private Flight Department        1  2.933333
# 2              WG Aero LLC    Private Flight Department        1  2.133333
# 3   Omni Air Transport LLC          Aircraft Management        1  2.300000
# 4    Pittsburgh Jet Center              Branded Charter        1  2.233333

# %%
# ------------------------------------------------------------
# STEP 1: LOAD DATA
# ------------------------------------------------------------

import pandas as pd
import numpy as np

url = "gs://agntworks-data-dev/wheelsup/processed/wingx/wingx_cluster_monthly_2023.csv"

df2 = pd.read_csv(url)

print("Shape:", df2.shape)
df2.head()
# Out:
# Shape: (473, 6)
#          cluster    month  inbound_hours  outbound_hours    total_hours  \
# 0  ASPEN_CLUSTER  2023-01  220348.711111   224681.746667  445030.457778
# 1  ASPEN_CLUSTER  2023-02  229211.955556   205471.582222  434683.537778
# 2  ASPEN_CLUSTER  2023-03  260934.397778   221519.484444  482453.882222
# 3  ASPEN_CLUSTER  2023-04   99796.175000   102563.133333  202359.308333
# 4  ASPEN_CLUSTER  2023-05  108442.376389    97523.220000  205965.596389
#
#    imbalance_ratio
# 0        -0.009736
# 1         0.054615
# 2         0.081697
# 3        -0.013673
# 4         0.053014

# %%
# ------------------------------------------------------------
# STEP 1: LOAD DATA
# ------------------------------------------------------------

import pandas as pd
import numpy as np

url = "gs://agntworks-data-dev/wheelsup/processed/wingx/wingx_corridor_monthly_2026.csv"

df3 = pd.read_csv(url)

print("Shape:", df3.shape)
df3.head()
# Out:
# Shape: (2698, 3)
#                         corridor    month       hours
# 0  ASPEN_CLUSTER→ATLANTA_CLUSTER  2026-01  250.933333
# 1  ASPEN_CLUSTER→ATLANTA_CLUSTER  2026-02  280.146667
# 2  ASPEN_CLUSTER→ATLANTA_CLUSTER  2026-03  346.903333
# 3   ASPEN_CLUSTER→BOSTON_CLUSTER  2026-01   62.928056
# 4   ASPEN_CLUSTER→BOSTON_CLUSTER  2026-02   71.983333
