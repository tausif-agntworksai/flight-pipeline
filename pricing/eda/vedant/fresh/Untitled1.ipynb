# %%
import pandas as pd
df=pd.read_csv("lj_comprehensive.csv")
df.columns
# Out:
# Index(['cluster_label', 'corridor', 'month', 'density_pct',
#        'seasonality_index', 'slab', 'intensity'],
#       dtype='object')

# %%
df[df["month"]=="May"]
# Out:
#                cluster_label                    corridor month  density_pct  \
# 4         winter-spring-peak          Atlanta -> Detroit   May         5.38
# 16        winter-spring-peak   Atlanta -> Phoenix Valley   May         8.82
# 28        winter-spring-peak          Bay Area -> Denver   May         7.03
# 40        winter-spring-peak         Bay Area -> Seattle   May         7.68
# 52        winter-spring-peak               Boston -> DMV   May         7.47
# ...                      ...                         ...   ...          ...
# 4264  multi-peak-directional            St. Louis -> DMV   May        11.64
# 4276  multi-peak-directional       St. Louis -> LA Basin   May         7.67
# 4288  multi-peak-directional    St. Louis -> Minneapolis   May         4.63
# 4300  multi-peak-directional  St. Louis -> North Florida   May         6.95
# 4312  multi-peak-directional   St. Louis -> Philadelphia   May        17.58
#
#       seasonality_index    slab  intensity
# ...
