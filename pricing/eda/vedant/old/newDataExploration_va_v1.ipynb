# %%
import pandas as pd

# %%
icao_metro_pairing= pd.read_csv('gs://agntworks-data-dev/wheelsup/raw/icao_metro_pairing.csv')

# %%
icao_metro_pairing.head()
# Out:
#   Atlanta North Florida South Florida Dallas St. Louis Minneapolis Denver  \
# 0    GE30          KBQK          PR20   41OK      70OK        SD87   SD04
# 1    2GE1          GE24          PR23   42OK      8OK8        SD57   KIEN
# 2    69FD          5FA2          PR33   50OK      KMIO        KPIR   KPHP
# 3    KEGI          FD53          PR10   77OK      88NE        KICR   SD07
# 4    0FD5          89FD          PR06   99OK      NE57        SD03   SD72
#
#   Philadelphia Nashville Detroit  ... Bay Area Boston Phoenix Valley Seattle  \
# 0         23JY      AR72    OI91  ...      DAF   LL59           KSGU    KSUN
# 1         8PA0      KFCY    7OA7  ...      U91   VT14           UT52    KTWF
# 2         PN44      70AR    OH77  ...      3U0   VT80           UT28    MT40
# 3         26PN      63AR    KILN  ...     5OR0   33VT           03UT    93MT
# 4         7PN3      7AR7    9OI4  ...     84OR   28VT           KMLF     53U
#
# ...

# %%
icao_metro_pairing.columns
# Out:
# Index(['Atlanta', 'North Florida', 'South Florida', 'Dallas', 'St. Louis',
#        'Minneapolis', 'Denver', 'Philadelphia', 'Nashville', 'Detroit',
#        'Pittsburgh', 'Chicago', 'Bay Area', 'Boston', 'Phoenix Valley',
#        'Seattle', 'DMV', 'New York City', 'Charlotte', 'Houston', 'LA Basin',
#        'San Antonio'],
#       dtype='object')

# %%
icao_metro_transformation_report = pd.read_csv('gs://agntworks-data-dev/wheelsup/processed/icao_metro_transformation_report_20260425.csv')

# %%
icao_metro_transformation_report.head()
# Out:
#            metro  source_count  transformed_count  match
# 0        Atlanta           700                700   True
# 1  North Florida           539                539   True
# 2  South Florida           306                306   True
# 3         Dallas          1206               1206   True
# 4      St. Louis          1052               1052   True

# %%
transformed_icao_metro = pd.read_csv('gs://agntworks-data-dev/wheelsup/processed/transformed_icao_metro.csv')

# %%
transformed_icao_metro.head()
# Out:
#    icao    metro
# 0  GE30  Atlanta
# 1  2GE1  Atlanta
# 2  69FD  Atlanta
# 3  KEGI  Atlanta
# 4  0FD5  Atlanta

# %%
df_bookings_metros = pd.read_parquet("gs://agntworks-data-dev/wheelsup/processed/df_bookings_metros.parquet")

# %%
df_bookings_metros[df_bookings_metros['flightactualAircraftCabinName'] == 'Light']
# Out:
#         flightId  atlasreservationid flightStatus  legOrder  \
# 0        1208327              794518    Cancelled         1
# 14       1208371              794548        Flown         1
# 15       1208372              794548        Flown         2
# 17       1208381              794555        Flown         2
# 18       1208387              794560        Flown         1
# ...          ...                 ...          ...       ...
# 258264   1290266              847514       Booked         1
# 258289   1285626              844549        Flown         2
# 258298   1283857              843435       Booked         1
# 258306   1291778              845924       Booked         3
# 258321   1290266              847514       Booked         1
#
#         flightoriginAirportId flightoriginAirport  \
# 0                         810                KTEB
# 14                        160                KBNA
# 15                       1026                KBCT
# ...

# %%
# df_bookings_metros.to_excel(
#     "df_bookings_metros.xlsx",
#     index=False,
#     engine="xlsxwriter"
# )
