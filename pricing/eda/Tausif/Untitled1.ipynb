# %% [markdown]
# 1. Flight Operations Analysis
# 🔹 Questions
# What is the on-time performance?
# % of flights delayed (Actual vs Estimated)
# What is the average delay (departure & arrival)?
# Which routes have highest delays?
# Which operators are least reliable?
# 💡 Insights
# Identify inefficient routes
# Detect underperforming operators
# 🎯 Business Impact
# Improve scheduling
# Replace or renegotiate operator contracts
# ✈️ 2. Route & Network Analysis
# 🔹 Questions
# Top most frequent routes (origin → destination)
# Routes with highest revenue (flightcost)
# Routes with low utilization but high cost
# 💡 Insights
# Core revenue-generating routes
# Loss-making routes
# 🎯 Business Impact
# Optimize route planning
# Drop or restructure weak routes
# 💰 3. Cost & Revenue Analysis
# 🔹 Questions
# Average cost per flight hour
# Cost variation by:
# Aircraft type
# Operator
# Difference between:
# Estimated vs Actual billed hours
# 💡 Insights
# Cost leakage (overbilling / inefficiency)
# Expensive aircraft types
# 🎯 Business Impact
# Cost optimization
# Better pricing strategy
# 🛫 4. Aircraft Utilization
# 🔹 Questions
# Which aircraft types are most used?
# Idle time between flights
# Requested vs actual aircraft mismatch
# 💡 Insights
# Underutilized aircraft
# Frequent substitutions
# 🎯 Business Impact
# Fleet optimization
# Better asset allocation
# 🧍 5. Customer / Booking Behavior
# 🔹 Questions
# Booking trends over time (from reservationCreateDate)
# Repeat customers (bookerMemberId)
# Peak booking periods
# 💡 Insights
# Seasonality patterns
# High-value customers
# 🎯 Business Impact
# Targeted marketing
# Demand forecasting
# 📊 6. Cancellation & Status Analysis
# 🔹 Questions
# Distribution of reservationStatus (cancelled, completed, etc.)
# Cancellation rate by route/operator
# 💡 Insights
# High-risk routes
# Poor service areas
# 🎯 Business Impact
# Reduce cancellations
# Improve customer satisfaction
# ⏱️ 7. Estimated vs Actual Performance
# 🔹 Questions
# Difference between:
# Estimated vs Actual flight hours
# Estimated vs Actual billed hours
# 💡 Insights
# Systematic under/over estimation
# Billing inefficiencies
# 🎯 Business Impact
# Improve estimation models
# Increase billing accuracy
# 🌍 8. Geographic Analysis
# 🔹 Questions
# Flights by country/state/city
# Most active regions
# Regional delay patterns
# 💡 Insights
# Strong vs weak markets
# Regional operational issues
# 🎯 Business Impact
# Expansion strategy
# Regional optimization
# 🏢 9. Operator Performance
# 🔹 Questions
# Flights per operator
# Delay rate per operator
# Cost per operator
# 💡 Insights
# Best & worst operators
# 🎯 Business Impact
# Vendor selection
# Contract negotiations
# 🧩 10. Data Quality & Missing Values (Very Important)
# 🔹 Questions
# Why are flightActualDepartureTime missing?
# Missing aircraft/cabin info patterns
# 💡 Insights
# Data pipeline issues
# Operational gaps
# 🎯 Business Impact
# Better reporting accuracy
# Reliable decision-making
# 🔥 High-Impact KPIs You Should Build
# On-time performance (%)
# Avg delay (minutes)
# Revenue per flight
# Cost per hour
# Aircraft utilization rate
# Cancellation rate
# Estimation accuracy %
# 🚀 Advanced (Interview-Level / Real Value)
# 🔹 Predictive Models
# Predict flight delays
# Predict flight cost
# Demand forecasting
# 🔹 Optimization
# Route optimization
# Fleet assignment optimization
# 🔹 Anomaly Detection
# Detect abnormal costs or delays
